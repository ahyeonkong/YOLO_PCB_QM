# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/yolo_test
# !unzip -qq "./YOLODataset.zip"
# !pip uninstall ultralytics -y
# !pip install ultralytics
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/yolo_test
# replace YOLODataset/dataset.yaml? [y]es, [n]o, [A]ll, [N]one, [r]ename: Found existing installation: ultralytics 8.2.64
# Uninstalling ultralytics-8.2.64:
#   Successfully uninstalled ultralytics-8.2.64
# ...
#   Using cached ultralytics-8.2.64-py3-none-any.whl.metadata (41 kB)
# ...
# Using cached ultralytics-8.2.64-py3-none-any.whl (824 kB)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/yolo_test
# Out:
# /content/gdrive/MyDrive/yolo_test

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model =YOLO("yolov8m.pt")

# %%
yaml_path ="/content/gdrive/MyDrive/yolo_test/YOLODataset/dataset.yaml"

# %%
model.train(data=yaml_path, epochs=30)
# Out:
# Ultralytics YOLOv8.2.64 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
import matplotlib.pyplot as plt

# %%
best_path = "/content/gdrive/MyDrive/yolo_test/runs/detect/train4/weights/best.pt"

# %%
model = YOLO(best_path)

# %%
#import cv2

img_path = "/content/gdrive/MyDrive/yolo_test/YOLODataset/images/train/cc2628553e2e84b8780637eb333a738c.png"
#img = cv2.imread(img_path)
result = model(img_path)[0]
plt.imshow(result.plot())
# Out:
# image 1/1 /content/gdrive/MyDrive/yolo_test/YOLODataset/images/train/cc2628553e2e84b8780637eb333a738c.png: 640x640 1 ink_error, 1533.6ms
# Speed: 3.6ms preprocess, 1533.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
