# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive/yolo_test
# Out:
# /content/gdrive/MyDrive/yolo_test

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model =YOLO("yolov8m.pt")

# %%
yaml_path ="/content/gdrive/MyDrive/yolo_test/testLabeling/data.yaml"

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.2.64

# %%
model.train(data=yaml_path, epochs=10)
# Out:
# Ultralytics YOLOv8.2.64 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
best_path = "/content/gdrive/MyDrive/yolo_test/runs/detect/train/weights/best.pt"

# %%
model = YOLO(best_path)

# %%
import cv2

img_path = "/content/gdrive/MyDrive/yolo_test/testLabeling/images/ink_error_1.jpg"
img = cv2.imread(img_path)
result = model(img)
plt.imshow(result[0].plot())
# Out:
# 0: 640x384 5 ink_errors, 1 AU_error, 24.7ms
# Speed: 3.2ms preprocess, 24.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
