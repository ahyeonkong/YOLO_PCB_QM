# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/yolo_test
# Out:
# /content/gdrive/MyDrive/yolo_test

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 11.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from ultralytics import YOLO

# %%
model =YOLO("yolov8m.pt")

# %%
yaml_path ="/content/gdrive/MyDrive/yolo_test/cropLabeling/data.yaml"

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6bf7c3e3e6fe> in <cell line: 1>()
# ----> 1 import ultralytics
#       2 print(ultralytics.__version__)
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
model.train(data=yaml_path, epochs=10)
# Out:
# Ultralytics YOLOv8.2.64 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import matplotlib.pyplot as plt

# %%
best_path = "/content/gdrive/MyDrive/yolo_test/runs/detect/train5/weights/best.pt"

# %%
model = YOLO(best_path)

# %%
# import cv2

img_path = "/content/gdrive/MyDrive/yolo_test/cropLabeling/images/crop_img_003.png"
# img = cv2.imread(img_path)
result = model(img_path)[0]
plt.imshow(result.plot())
# Out:
# image 1/1 /content/gdrive/MyDrive/yolo_test/cropLabeling/images/crop_img_003.png: 640x640 2 AU_errors, 2926.2ms
# Speed: 11.6ms preprocess, 2926.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
